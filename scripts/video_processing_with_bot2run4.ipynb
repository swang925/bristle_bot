# %%
## Run this to Setup the Environment
import cv2 as cv
from matplotlib import pyplot as plt
import os
import numpy as np
import random as rng
rootPath = 'D:/AMEP lab/BBot Database'

"""
    Purpose of this script is to capture the ellipse that surrounds the robot
    in one experiment file
    The result is not perfect, but it should capture as many data as possible
    Even if it means noise is included. All signals should be included
"""
# Out:
# '\n    Purpose of this script is to capture the ellipse that surrounds the robot\n    in one experiment file\n    The result is not perfect, but it should capture as many data as possible\n    Even if it means noise is included. All signals should be included\n'

# %%
"""
  DO NOT RUN THIS IF FRAMES ALREADY LOADED! IT TAKES LONG!
  This part of the code is for writing the input video into frames
"""
print(os.getcwd())
print(os.listdir())

cap = cv.VideoCapture(rootPath+'/input/videos/bot2run4.MOV')
if (cap.isOpened()== False):
  print("Error opening video stream or file")

# Frame number called flag
flag = 0
# Read until video is completed
while(cap.isOpened()):
  # Capture frame-by-frame
  ret, frame = cap.read()
  if ret == True:
    flag+=1
    cv.imwrite("bot2run4/"+str(flag)+".jpg", frame)
  # Break the loop
  else:
    break
# Out:
# /content/drive/MyDrive/Colab Notebooks/BBot project
# ['DSC_5815.JPG', 'DSC_5816.JPG', 'DSC_5823.JPG', 'DSC_5824.JPG', 'DSC_5825.JPG', 'DSC_5826.JPG', 'bot2run3.MOV', 'bot2run3', 'image processing with bot2run3.ipynb', 'bot2run4.MOV', 'bot2run4', 'bot2run5.MOV', 'surface stats.gsheet', 'video analysis with bot2.ipynb', 'outpy.avi', 'sample_frame_bot2.jpg', 'sample_frame_bot3.jpg', 'video processing with bot2run4.ipynb']

# %%
## Find the video frame that would work as a background image
path = rootPath+"/input/frames/bot2run4/1.jpg" #REMEMBER: path has to use '/' instead of '\'
background = cv.imread(path)
plt.imshow(convertToDisplay(np.array(background)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\AMEP lab\BBot Database\scripts\video_processing_with_bot2run4.ipynb Cell 3 in 4
#       <a href='vscode-notebook-cell:/d%3A/AMEP%20lab/BBot%20Database/scripts/video_processing_with_bot2run4.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> path = rootPath+"/input/frames/bot2run4/1.jpg" #REMEMBER: path has to use '/' instead of '\'
#       <a href='vscode-notebook-cell:/d%3A/AMEP%20lab/BBot%20Database/scripts/video_processing_with_bot2run4.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> background = cv.imread(path)
# ----> <a href='vscode-notebook-cell:/d%3A/AMEP%20lab/BBot%20Database/scripts/video_processing_with_bot2run4.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> plt.imshow(convertToDisplay(np.array(background)))
#
# d:\AMEP lab\BBot Database\scripts\video_processing_with_bot2run4.ipynb Cell 3 in 1
#      <a href='vscode-notebook-cell:/d%3A/AMEP%20lab/BBot%20Database/scripts/video_processing_with_bot2run4.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a> for pi, pixel in enumerate(row):
#      <a href='vscode-notebook-cell:/d%3A/AMEP%20lab/BBot%20Database/scripts/video_processing_with_bot2run4.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a>     converted[ri][pi] = [pixel[2], pixel[1], pixel[0]]
# ---> <a href='vscode-notebook-cell:/d%3A/AMEP%20lab/BBot%20Database/scripts/video_processing_with_bot2run4.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a>     reds += [pixel[2]]
#      <a href='vscode-notebook-cell:/d%3A/AMEP%20lab/BBot%20Database/scripts/video_processing_with_bot2run4.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a>     blues += [pixel[0]]
#      <a href='vscode-notebook-cell:/d%3A/AMEP%20lab/BBot%20Database/scripts/video_processing_with_bot2run4.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a>     greens += [pixel[1]]
#
# NameError: name 'reds' is not defined

# %% [markdown]
# Find the contrast image with only the robot \
# Threshold the image so that there shows a clean robot \
# Get the Stats of this robot

# %%
def convertToDisplay(frame):
    """
    This function helps you arrange the data output of cv.imread() which is in BGR format
    into RGB format which is the input format of plt.imshow()

    It takes a cv Mat variable and returns a np.array()
    """
    converted = np.zeros((frame.shape[0], frame.shape[1], frame.shape[2]), dtype=np.int16)
    global blues, greens, reds
    for ri, row in enumerate(frame):
        for pi, pixel in enumerate(row):
            converted[ri][pi] = [pixel[2], pixel[1], pixel[0]]
            reds += [pixel[2]]
            blues += [pixel[0]]
            greens += [pixel[1]]
    return converted

def GetEllipseFrom(frame): #frame must be a np.array()
  """
  Returns an ellipse object
  locate the robot object in the frame and identifies it with a minimum area ellipse around it
  
  """

  frame = frame.astype('uint8')
  frame = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)

  #plt.imshow(frame)
  #Find all the contours in this frame
  contours,_= cv.findContours(image=frame,
                              mode=cv.RETR_TREE,
                              method=cv.CHAIN_APPROX_NONE,
                             )

  #Find out all the ellipse corresponding to the contours in this frame:
  minEllipse = [None]*len(contours)
  for i,c in enumerate(contours):
    if c.shape[0] > 5:
      minEllipse[i] = cv.fitEllipse(c)

  return minEllipse

# %%
# Picking out one frame with the robot and do Analysis on it, if it works, we do that for all frames
i = 200 
framePath = rootPath+"/input/frames/bot2run4/{}.jpg".format(i)
robot = cv.imread(framePath)

robotOnly = cv.subtract(robot, background) # Subtract background from robot, leaving only the robot image, otherwise black

# %%
#Run this part to load the image again
blues = []
greens = []
reds = []
#Blur the robotOnly image
robotOnly = cv.GaussianBlur(robotOnly,(11,11),0)

#Create canvas for the new robotBinary image, which is a weighted image of the robotBinary image


robotBinary = convertToDisplay(robotOnly)
plt.imshow(robotBinary)
#This show that the robotBinary image is dimmed from the original image because of the subtraction of background

# %%
# Masking
robotBinary[robotBinary > 160] = 255# recommend 25 as threshold for frame 
robotBinary[robotBinary < 160] = 0

# %%
# find all the ellipses in the robotOnly frame
minEllipse = GetEllipseFrom(robotBinary)

# create this empty canvas from robotOnly dimensions
drawing = np.zeros((robotBinary.shape[0], robotBinary.shape[1], robotBinary.shape[2]), dtype=np.uint8)

# draw ellipse
for i, e in enumerate(minEllipse):
    color = (rng.randint(0,256), rng.randint(0,256), rng.randint(0,256))
    cv.ellipse(drawing, minEllipse[i], color, 2)

plt.imshow(drawing)

# %%
# Store all frames as binary frames to a .npy file
# MASK IT!
path = rootPath+"/input/frames/bot2run4" #REMEMBER: path has to use '/' instead of '\'
background = cv.imread(path+'/1.jpg')

numberOfFrames = len(os.listdir(path))
center = np.zeros((numberOfFrames,2))
size = np.zeros((numberOfFrames,2))
angle = np.zeros((numberOfFrames,1))

for i in range(numberOfFrames):
    robot = cv.imread(path+'/{}.jpg'.format(i+1)) # Configure this according to the directory
    robotOnly = cv.subtract(robot, background) # Subtract background from robot, leaving only the robot image, otherwise black
    robotBinary = cv.GaussianBlur(robotOnly,(11,11),0) # Blur the image. This is Tunable parameter

    _, minEllipse = dynamicMask(robotBinary, 10)

    # Putting all the variables where they belong, indexing may create problems, but in general 
    # try-except block captures all the data
    #TODO: Need to look more into this part, since there might be signals missing because of this
    #      brute-force processing
    try:
        center[i] = minEllipse[0][0]
        size[i] = minEllipse[0][1]
        angle[i] = minEllipse[0][2]
    except:
        center[i] = (-1, -1)
        size[i] = (-1, -1)
        angle[i] = [-1]
    print('Finished Working on Frame_{}'.format(i+1))

path = rootPath+'/output/data/bot2run4/center.npy'
np.save(path, np.asarray(center))
path = rootPath+'/output/data/bot2run4/size.npy'
np.save(path, size)
path = rootPath+'/output/data/bot2run4/angle.npy'
np.save(path, angle)
# Out:
# Finished Working on Frame_1
# Finished Working on Frame_2
# Finished Working on Frame_3
# Finished Working on Frame_4
# Finished Working on Frame_5
# Finished Working on Frame_6
# Finished Working on Frame_7
# Finished Working on Frame_8
# Finished Working on Frame_9
# Finished Working on Frame_10
# Finished Working on Frame_11
# Finished Working on Frame_12
# Finished Working on Frame_13
# Finished Working on Frame_14
# Finished Working on Frame_15
# Finished Working on Frame_16
# Finished Working on Frame_17
# Finished Working on Frame_18
# Finished Working on Frame_19
# Finished Working on Frame_20
# Finished Working on Frame_21
# Finished Working on Frame_22
# Finished Working on Frame_23
# Finished Working on Frame_24
# Finished Working on Frame_25
# Finished Working on Frame_26
# Finished Working on Frame_27
# Finished Working on Frame_28
# Finished Working on Frame_29
# Finished Working on Frame_30
# Finished Working on Frame_31
# Finished Working on Frame_32
# Finished Working on Frame_33
# Finished Working on Frame_34
# Finished Working on Frame_35
# Finished Working on Frame_36
# Finished Working on Frame_37
# Finished Working on Frame_38
# Finished Working on Frame_39
# Finished Working on Frame_40
# Finished Working on Frame_41
# Finished Working on Frame_42
# Finished Working on Frame_43
# Finished Working on Frame_44
# Finished Working on Frame_45
# Finished Working on Frame_46
# Finished Working on Frame_47
# Finished Working on Frame_48
# Finished Working on Frame_49
# Finished Working on Frame_50
# Finished Working on Frame_51
# Finished Working on Frame_52
# Finished Working on Frame_53
# Finished Working on Frame_54
# Finished Working on Frame_55
# Finished Working on Frame_56
# Finished Working on Frame_57
# Finished Working on Frame_58
# Finished Working on Frame_59
# Finished Working on Frame_60
# Finished Working on Frame_61
# Finished Working on Frame_62
# Finished Working on Frame_63
# Finished Working on Frame_64
# Finished Working on Frame_65
# Finished Working on Frame_66
# Finished Working on Frame_67
# Finished Working on Frame_68
# Finished Working on Frame_69
# Finished Working on Frame_70
# Finished Working on Frame_71
# Finished Working on Frame_72
# Finished Working on Frame_73
# Finished Working on Frame_74
# Finished Working on Frame_75
# Finished Working on Frame_76
# Finished Working on Frame_77
# Finished Working on Frame_78
# Finished Working on Frame_79
# Finished Working on Frame_80
# Finished Working on Frame_81
# Finished Working on Frame_82
# Finished Working on Frame_83
# Finished Working on Frame_84
# Finished Working on Frame_85
# Finished Working on Frame_86
# Finished Working on Frame_87
# Finished Working on Frame_88
# Finished Working on Frame_89
# Finished Working on Frame_90
# Finished Working on Frame_91
# Finished Working on Frame_92
# Finished Working on Frame_93
# Finished Working on Frame_94
# Finished Working on Frame_95
# Finished Working on Frame_96
# Finished Working on Frame_97
# Finished Working on Frame_775
# Finished Working on Frame_776
# Finished Working on Frame_777
# Finished Working on Frame_778
# Finished Working on Frame_779
# Finished Working on Frame_780
# Finished Working on Frame_781
# Finished Working on Frame_782
# Finished Working on Frame_783
# Finished Working on Frame_784
# Finished Working on Frame_785
# Finished Working on Frame_786
# Finished Working on Frame_787
# Finished Working on Frame_788
# Finished Working on Frame_789
# Finished Working on Frame_790
# Finished Working on Frame_791
# Finished Working on Frame_792
# Finished Working on Frame_793
# Finished Working on Frame_794
# Finished Working on Frame_795
# Finished Working on Frame_796
# Finished Working on Frame_797
# Finished Working on Frame_798
# Finished Working on Frame_799
# Finished Working on Frame_800
# Finished Working on Frame_801
# Finished Working on Frame_802
# Finished Working on Frame_803
# Finished Working on Frame_804
# Finished Working on Frame_805
# Finished Working on Frame_806
# Finished Working on Frame_807
# Finished Working on Frame_808
# Finished Working on Frame_809
# Finished Working on Frame_810
# Finished Working on Frame_811
# Finished Working on Frame_812
# Finished Working on Frame_813
# Finished Working on Frame_814
# Finished Working on Frame_815
# Finished Working on Frame_816
# Finished Working on Frame_817
# Finished Working on Frame_818
# Finished Working on Frame_819
# Finished Working on Frame_820
# Finished Working on Frame_821
# Finished Working on Frame_822
# Finished Working on Frame_823
# Finished Working on Frame_824
# Finished Working on Frame_825
# Finished Working on Frame_826
# Finished Working on Frame_827
# Finished Working on Frame_828
# Finished Working on Frame_829
# Finished Working on Frame_830
# Finished Working on Frame_831
# Finished Working on Frame_832
# Finished Working on Frame_833
# Finished Working on Frame_834
# Finished Working on Frame_835
# Finished Working on Frame_836
# Finished Working on Frame_837
# Finished Working on Frame_838
# Finished Working on Frame_839
# Finished Working on Frame_840
# Finished Working on Frame_841
# Finished Working on Frame_842
# Finished Working on Frame_843
# Finished Working on Frame_844
# Finished Working on Frame_845
# Finished Working on Frame_846
# Finished Working on Frame_847
# Finished Working on Frame_848
# Finished Working on Frame_849
# Finished Working on Frame_850
# Finished Working on Frame_851
# Finished Working on Frame_852
# Finished Working on Frame_853
# Finished Working on Frame_854
# Finished Working on Frame_855
# Finished Working on Frame_856
# Finished Working on Frame_857
# Finished Working on Frame_858
# Finished Working on Frame_859
# Finished Working on Frame_860
# Finished Working on Frame_861
# Finished Working on Frame_862
# Finished Working on Frame_863
# Finished Working on Frame_864
# Finished Working on Frame_865
# Finished Working on Frame_866
# Finished Working on Frame_867
# Finished Working on Frame_868
# Finished Working on Frame_869
# Finished Working on Frame_870
# Finished Working on Frame_871
# Finished Working on Frame_872
# Finished Working on Frame_873
# Finished Working on Frame_874
# Finished Working on Frame_875
# Finished Working on Frame_876
# Finished Working on Frame_877
# Finished Working on Frame_878
# Finished Working on Frame_879
# Finished Working on Frame_880
# Finished Working on Frame_881
# Finished Working on Frame_882
# Finished Working on Frame_883
# Finished Working on Frame_884
# Finished Working on Frame_885

# %%
# Do findEllipse on the .npy file
